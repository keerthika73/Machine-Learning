# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/data excel.csv')
df.head()
# Out:
#   Class          I0     PA500       HFS          DA          Area        ADA  \
# 0   car  524.794072  0.187448  0.032114  228.800228   6843.598481  29.910803
# 1   car  330.000000  0.226893  0.265290  121.154201   3163.239472  26.109202
# 2   car  551.879287  0.232478  0.063530  264.804935  11888.391830  44.894903
# 3   car  380.000000  0.240855  0.286234  345.837800   5402.171180        NaN
# 4   car  362.831266  0.200713  0.244346  124.912559   3290.462446        NaN
#
#        MAXIP          DR           P
# 0  60.204880  220.737212  556.828334
# 1  69.717361   99.084964  400.225776
# 2  77.793297  253.785300  656.769449
# 3  88.758446  105.198568  493.701814
# 4  69.389389  103.866552  424.796503

# %%
df.isnull().sum()
# Out:
# Class    0
# I0       0
# PA500    0
# HFS      0
# DA       0
# Area     0
# ADA      6
# MAXIP    0
# DR       0
# P        0
# dtype: int64

# %%
null=df.ADA.mean()
null
# Out:
# np.float64(22.810853974040004)

# %%
df.ADA=df.ADA.fillna(null)

# %%
df.isnull().sum()
# Out:
# Class    0
# I0       0
# PA500    0
# HFS      0
# DA       0
# Area     0
# ADA      0
# MAXIP    0
# DR       0
# P        0
# dtype: int64

# %%
df
# Out:
#     Class           I0     PA500       HFS           DA           Area  \
# 0     car   524.794072  0.187448  0.032114   228.800228    6843.598481
# 1     car   330.000000  0.226893  0.265290   121.154201    3163.239472
# 2     car   551.879287  0.232478  0.063530   264.804935   11888.391830
# 3     car   380.000000  0.240855  0.286234   345.837800    5402.171180
# 4     car   362.831266  0.200713  0.244346   124.912559    3290.462446
# ..    ...          ...       ...       ...          ...            ...
# 101   adi  2000.000000  0.106989  0.105418   520.222649   40087.920980
# 102   adi  2600.000000  0.200538  0.208043  1063.441427  174480.476200
# 103   adi  1600.000000  0.071908 -0.066323   436.943603   12655.342130
# 104   adi  2300.000000  0.045029  0.136834   185.446044    5086.292497
# 105   adi  2600.000000  0.069988  0.048869   745.474369   39845.773700
#
#             ADA       MAXIP          DR            P
# 0     29.910803   60.204880  220.737212   556.828334
# ...

# %%
df.head()
# Out:
#   Class          I0     PA500       HFS          DA          Area        ADA  \
# 0   car  524.794072  0.187448  0.032114  228.800228   6843.598481  29.910803
# 1   car  330.000000  0.226893  0.265290  121.154201   3163.239472  26.109202
# 2   car  551.879287  0.232478  0.063530  264.804935  11888.391830  44.894903
# 3   car  380.000000  0.240855  0.286234  345.837800   5402.171180  22.810854
# 4   car  362.831266  0.200713  0.244346  124.912559   3290.462446  22.810854
#
#        MAXIP          DR           P
# 0  60.204880  220.737212  556.828334
# 1  69.717361   99.084964  400.225776
# 2  77.793297  253.785300  656.769449
# 3  88.758446  105.198568  493.701814
# 4  69.389389  103.866552  424.796503

# %%
x=df.drop(['P'],axis=1)
x
# Out:
#     Class           I0     PA500       HFS           DA           Area  \
# 0     car   524.794072  0.187448  0.032114   228.800228    6843.598481
# 1     car   330.000000  0.226893  0.265290   121.154201    3163.239472
# 2     car   551.879287  0.232478  0.063530   264.804935   11888.391830
# 3     car   380.000000  0.240855  0.286234   345.837800    5402.171180
# 4     car   362.831266  0.200713  0.244346   124.912559    3290.462446
# ..    ...          ...       ...       ...          ...            ...
# 101   adi  2000.000000  0.106989  0.105418   520.222649   40087.920980
# 102   adi  2600.000000  0.200538  0.208043  1063.441427  174480.476200
# 103   adi  1600.000000  0.071908 -0.066323   436.943603   12655.342130
# 104   adi  2300.000000  0.045029  0.136834   185.446044    5086.292497
# 105   adi  2600.000000  0.069988  0.048869   745.474369   39845.773700
#
#             ADA       MAXIP          DR
# 0     29.910803   60.204880  220.737212
# ...

# %%
y=df['P']
y
# Out:
# 0       556.828334
# 1       400.225776
# 2       656.769449
# 3       493.701814
# 4       424.796503
#           ...
# 101    2088.648870
# 102    2664.583623
# 103    1475.371534
# 104    2480.592151
# 105    2545.419744
# Name: P, Length: 106, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=37)
x_train
# Out:
#    Class           I0     PA500       HFS          DA          Area  \
# 39   mas   250.000000  0.047124  0.013963   70.907040    224.145787
# 73   con   649.369397  0.107512  0.018850  207.111691   3344.432678
# 55   gla   223.000000  0.124093  0.079587   33.096335    197.012541
# 57   gla   303.000000  0.063355  0.039794   22.567893    102.500309
# 94   adi  1800.000000  0.069115  0.157080  385.564704  13831.724890
# ..   ...          ...       ...       ...         ...           ...
# 22   fad   196.856714  0.020071  0.090757   28.593126     82.058889
# 53   mas   327.000000  0.141023  0.084474   76.212868   1664.674076
# 92   adi  1800.000000  0.091979  0.205251  362.863321  15021.553890
# 76   con   650.000000  0.041015  0.145211  216.811330    427.534068
# 15   car   390.000000  0.358316  0.203854  245.686103  10055.836870
#
#           ADA       MAXIP          DR
# 39   3.161122    9.102176   70.320400
# 73  16.147967   50.547470  200.848714
# ...

# %%
x_test
# Out:
#     Class           I0     PA500       HFS           DA          Area  \
# 83    con  1535.850740  0.088488  0.004189   637.349674  10814.050170
# 10    car   410.000000  0.317824  0.297404   383.669000  10622.547110
# 101   adi  2000.000000  0.106989  0.105418   520.222649  40087.920980
# 103   adi  1600.000000  0.071908 -0.066323   436.943603  12655.342130
# 41    mas   236.000000  0.124617  0.201760    48.451130    236.880111
# 5     car   389.872978  0.150098  0.097738  1223.470000   2475.557078
# 38    mas   435.093167  0.076969  0.161268   123.597538   1342.277648
# 91    adi  2350.000000  0.081507  0.271573   515.289477  27758.640260
# 79    con  1496.736054  0.103847  0.082380   640.275950  11071.997800
# 96    adi  1650.000000  0.047647  0.043284   274.426177   5824.895192
# 18    car   325.000000  0.224624  0.286932   229.215863   5705.332090
# 66    gla   176.000000  0.089884  0.076794    20.588524     79.705425
# ...

# %%
x_train = pd.get_dummies(x_train)
x_test = pd.get_dummies(x_test)


x_train, x_test = x_train.align(x_test,axis=1)

# %%
svmAlgo = SVR()

# %%
model = svmAlgo.fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# -0.20609578596940192

# %%
model.score(x_test,y_test)
# Out:
# -0.15542752789662662
