# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
iris=pd.read_csv(r"/content/IRIS (1).csv")

# %%
iris.head()

# %%
print(iris.shape)
# Out:
# (150, 4)

# %%
sns.set(style='darkgrid',rc={'figure.figsize':(8,5)},font_scale=0.3)

# %%
sns.displot(iris['sepal_length'])

# %%
sns.displot
# Out:
# <function seaborn.distributions.displot(data=None, *, x=None, y=None, hue=None, row=None, col=None, weights=None, kind='hist', rug=False, rug_kws=None, log_scale=None, legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, row_order=None, col_order=None, height=5, aspect=1, facet_kws=None, **kwargs)>

# %%
sns.displot(iris['sepal_length'],bins=20)

# %%
sns.displot(iris['sepal_length'],kde=True)

# %%
sns.distplot(iris['sepal_length'], hist = False, vertical= True, color = 'purple')
# Out:
# /tmp/ipython-input-62-651823025.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['sepal_length'], hist = False, vertical= True, color = 'purple')
# <Axes: xlabel='Density', ylabel='sepal_length'>

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='hex')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='kde')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='kde',color='green')

# %%
sns.pairplot(iris)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
sns.pairplot(iris,hue='petal_width')

# %%
sns.pairplot(iris,hue='petal_width',palette='coolwarm')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
sns.barplot(x='petal_width',y='sepal_length',data=iris)
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.barplot(x='petal_width',y='sepal_length',data=iris,hue='petal_length')
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.barplot(x='petal_width',y='sepal_length',data=iris,hue='petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.barplot(x='petal_width',y='sepal_length',data=iris,hue='petal_width',estimator=np.std)
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.countplot(x='petal_width',data=iris)
# Out:
# <Axes: xlabel='petal_width', ylabel='count'>

# %%
sns.countplot(x='petal_width',data=iris,hue='petal_length')
# Out:
# <Axes: xlabel='petal_width', ylabel='count'>

# %%
sns.countplot(x='petal_length',data=iris,hue='petal_width',color='yellow')
# Out:
# /tmp/ipython-input-93-836468943.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:yellow'` for the same effect.
#
#   sns.countplot(x='petal_length',data=iris,hue='petal_width',color='yellow')
# <Axes: xlabel='petal_length', ylabel='count'>

# %%
sns.countplot(x='petal_length',data=iris,hue='petal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='count'>

# %%
sns.boxplot(x='petal_length',y='sepal_length',data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.boxplot(x='petal_length',y='sepal_length',data=iris,hue='petal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.violinplot(x='petal_length',y='sepal_length',data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.violinplot(x='petal_length',y='sepal_length',data=iris,hue='petal_width',split=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.stripplot(x='petal_length',y='sepal_length',data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
pip install sns
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sns: filename=sns-0.1-py3-none-any.whl size=2639 sha256=33b1e17fd8aaa6142e0bcbee264d4122a054f87b6f5faf4742ef35e5cc444d17
#   Stored in directory: /root/.cache/pip/wheels/7c/e1/f6/7f1e51e342bccba75ac6cfae60918407acaa6999034889d25e
# Successfully built sns
# ...

# %%
sns.catplot(x = 'petal_length', y = 'sepal_width', data = iris, kind = 'box', hue = 'petal_width')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
ic=iris.corr()

# %%
sns.heatmap(ic)
# Out:
# <Axes: >

# %%
sns.heatmap(ic,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(ic,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')
fp.head()
# Out:
# /tmp/ipython-input-148-2632806788.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp=flights.pivot_table(index='month',columns='year',values='passengers')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0

# %%
sns.heatmap(fp)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidths=2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp,cmap='coolwarm')

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.PairGrid(iris)

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g=sns.PairGrid(iris)

g.map_lower(sns.kdeplot)

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set(font_scale = 1)

# %%
g=sns.FacetGrid(data=iris,col='sepal_width',row='petal_width')
g.map(sns.distplot,'petal_length')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
g=sns.FacetGrid(data=iris,col='sepal_width',row='petal_width')
g.map(plt.scatter,'petal_length','petal_width')

# %%
iris.head()

# %%
sns.lmplot(x='petal_length',y='petal_width',data=iris)

# %%
sns.lmplot(x='petal_length',y='petal_width',data=iris,hue='sepal_width')

# %%
sns.lmplot(x='petal_length',y='petal_width',data=iris,hue='sepal_width',markers=['o','v'])

# %%
sns.lmplot(x='petal_length',y='petal_width',data=iris,col='sepal_width')

# %%
sns.lmplot(x='petal_length',y='petal_width',data=iris,col='sepal_width',row='flower')
