# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(3,30,10)
y=x**2

# %%
x
# Out:
# array([ 3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.])

# %%
y
# Out:
# array([  9.,  36.,  81., 144., 225., 324., 441., 576., 729., 900.])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.plot(x,y)
plt.show()

# %%
x1=np.linspace(-np.pi,np.pi,373)
x2=np.linspace(-np.pi,np.pi,373)
y1=np.cos(x1)
y2=np.sin(x2)
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,'c--')
plt.plot(x2,y2,'m--')
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,color='green')
plt.plot(x2,y2,color='brown')
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,color='green',lw=0.8)
plt.plot(x2,y2,color='brown',lw=0.8)
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,color='green',lw=1.9,ls=':')
plt.plot(x2,y2,color='brown',lw=1.9,ls='-.')

plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,color='green',lw=1.9,ls=':')
plt.plot(x2,y2,color='brown',lw=1.9,ls='-.')
plt.xticks([-3.14,-3.14/2,0,3.14/2,3.14])
plt.yticks([-2,-1,0,1,2])
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,color='green',lw=1.9,ls=':')
plt.plot(x2,y2,color='brown',lw=1.9,ls='-.')
plt.xticks([-3.14,-3.14/2,0,3.14/2,3.14]),[r'-3.14,-3.14/2,0,3.14/2,3.14']
plt.yticks([-2,-1,0,1,2])
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot(x1,y1,color='green',lw=1.9,ls=':',label='x=cos')
plt.plot(x2,y2,color='brown',lw=1.9,ls='-.',label='y=sin')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.xticks([-3.14,-3.14/2,0,3.14/2,3.14],[-3.14,-3.14/2,0,3.14/2,3.14])
plt.yticks([-2,-1,0,1,2])
plt.legend(loc=0)
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.plot([3,6,9,7,8],[4,7,10,8,9],color='green',lw=1.9,marker='o',mec='yellow',mew=3)
plt.show()

# %%
x=np.array([2,4,6,8,9])
y1=x**2
y2=np.exp(x)
plt.figure(figsize=(5,3),dpi=100)
plt.subplot(1,2,1)
plt.plot(x,y1,'g-.')
plt.subplot(1,2,2)
plt.plot(x,y2,'r-')

# %%
x=np.array([2,4,5,7,8,10,12,15,16,17])
y=x**2
fig=plt.figure(figsize=(5,3))
axes=fig.add_axes([0.2,0.4,0.6,0.8])
axes.plot(x,y)
plt.show()

# %%
fig=plt.figure(figsize=(5,3))
axes1=fig.add_axes([0.2,0.4,0.6,0.8])
axes2=fig.add_axes([0.3,0.80,0.2,0.3])
axes1.plot(x,y,'g-.')
axes1.set_title('big box')
axes2.plot(y,x,'r-')
axes2.set_title('small box')
# Out:
# Text(0.5, 1.0, 'small box')

# %%
fig=plt.figure(figsize=(9,5))
axes=fig.subplots(3,3)

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
fig=plt.figure(figsize=(9,5))
axes=fig.subplots(3,3)

# %%
fig=plt.figure(figsize=(9,5))
axes=fig.subplots(2,3)
axes[0,0].plot(x,y,'g-.')
axes[0][0].set_title('0,0')
axes[0][1].plot(x,y,'bo')
axes[0][1].set_title('0,1')
axes[0][2].plot(x,y,'p-')
axes[0][2].set_title('0,2')
axes[1][0].plot(x,y,'r--')
axes[1][0].set_title('1,0')
fig.tight_layout()

# %%
t=np.arange(0,3,0.3)
s=1+np.sin(2*np.pi*t)
fig,ax=plt.subplots()
ax.plot(t,s)
ax.set_xlabel('time')
ax.set_ylabel('voltage')
ax.set_title('graph')
ax.grid()
plt.show()

# %%
x=np.random.randint(80,size=20)
y=np.random.randint(80,size=20)
plt.scatter(x,y,marker='o')

# %%
from mpl_toolkits import mplot3d
fig=plt.figure(figsize=(15,8))
ax=plt.axes(projection='3d')

# %%
fig=plt.figure(figsize=(15,8))
ax=plt.axes(projection='3d')
zline=np.linspace(0,10,500)
xline=np.sin(zline)
yline=np.cos(zline)
ax.plot3D(xline,yline,zline,'green')

# %%
fig=plt.figure(figsize=(15,8))
ax=plt.axes(projection='3d')
x=np.random.randint(80,size=250)
y=np.random.randint(80,size=250)
z=np.random.randint(80,size=250)
ax.scatter3D(x,y,z,c='Green')

# %%
def f(x,y):
  return np.sin(np.sqrt(x**2+y**2))

# %%
r=np.linspace(1,10,20)
theta=np.linspace(-0.7*3.14,0.9*3.14,70)

r,theta = np.meshgrid(r, theta)

X=r*np.sin(theta)
Y=r*np.cos(theta)
Z=f(X,Y)
fig=plt.figure(figsize=(15,8))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z,cmap='viridis')
plt.show()

# %%
fig.savefig('test.pdf',dpi=300)
